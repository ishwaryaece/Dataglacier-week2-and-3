# %%
#G2M insight for Cab Investment firm
#import required library
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt

# %%
#Read and understand datatype
#1.Cab_data
cab_df = pd.read_csv('Cab_Data.csv')
cab_df.head()
# Out:
#    Transaction ID  Date of Travel   Company        City  KM Travelled  \
# 0        10000011           42377  Pink Cab  ATLANTA GA         30.45
# 1        10000012           42375  Pink Cab  ATLANTA GA         28.62
# 2        10000013           42371  Pink Cab  ATLANTA GA          9.04
# 3        10000014           42376  Pink Cab  ATLANTA GA         33.17
# 4        10000015           42372  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged  Cost of Trip
# 0         370.95       313.635
# 1         358.52       334.854
# 2         125.20        97.632
# 3         377.40       351.602
# 4         114.62        97.776

# %%
cab_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359392 entries, 0 to 359391
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  359392 non-null  int64
#  1   Date of Travel  359392 non-null  int64
#  2   Company         359392 non-null  object
#  3   City            359392 non-null  object
#  4   KM Travelled    359392 non-null  float64
#  5   Price Charged   359392 non-null  float64
#  6   Cost of Trip    359392 non-null  float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 19.2+ MB

# %%
cab_df.dtypes
# Out:
# Transaction ID      int64
# Date of Travel      int64
# Company            object
# City               object
# KM Travelled      float64
# Price Charged     float64
# Cost of Trip      float64
# dtype: object

# %%
cab_df.describe()
# Out:
#        Transaction ID  Date of Travel   KM Travelled  Price Charged  \
# count    3.593920e+05   359392.000000  359392.000000  359392.000000
# mean     1.022076e+07    42964.067998      22.567254     423.443311
# std      1.268058e+05      307.467197      12.233526     274.378911
# min      1.000001e+07    42371.000000       1.900000      15.600000
# 25%      1.011081e+07    42697.000000      12.000000     206.437500
# 50%      1.022104e+07    42988.000000      22.440000     386.360000
# 75%      1.033094e+07    43232.000000      32.960000     583.660000
# max      1.044011e+07    43465.000000      48.000000    2048.030000
#
#         Cost of Trip
# count  359392.000000
# mean      286.190113
# std       157.993661
# min        19.000000
# 25%       151.200000
# 50%       282.480000
# 75%       413.683200
# max       691.200000

# %%
#Read and understand datatype
#2.city
city_df = pd.read_csv('City.csv')
city_df.head()
# Out:
#              City   Population      Users
# 0     NEW YORK NY   8,405,837    302,149
# 1      CHICAGO IL   1,955,130    164,468
# 2  LOS ANGELES CA   1,595,037    144,132
# 3        MIAMI FL   1,339,155     17,675
# 4  SILICON VALLEY   1,177,609     27,247

# %%
city_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        20 non-null     object
#  1   Population  20 non-null     object
#  2   Users       20 non-null     object
# dtypes: object(3)
# memory usage: 608.0+ bytes

# %%
city_df.dtypes
# Out:
# City          object
# Population    object
# Users         object
# dtype: object

# %%
city_df.describe()
# Out:
#                City   Population      Users
# count            20           20         20
# unique           20           20         20
# top     NEW YORK NY   8,405,837    302,149
# freq              1            1          1

# %%
#Read and understand datatype
#3.customer ID
customer_id_df = pd.read_csv('Customer_ID.csv')
customer_id_df.head()
# Out:
#    Customer ID Gender  Age  Income (USD/Month)
# 0        29290   Male   28               10813
# 1        27703   Male   27                9237
# 2        28712   Male   53               11242
# 3        28020   Male   23               23327
# 4        27182   Male   33                8536

# %%
customer_id_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49171 entries, 0 to 49170
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer ID         49171 non-null  int64
#  1   Gender              49171 non-null  object
#  2   Age                 49171 non-null  int64
#  3   Income (USD/Month)  49171 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %%
customer_id_df.dtypes
# Out:
# Customer ID            int64
# Gender                object
# Age                    int64
# Income (USD/Month)     int64
# dtype: object

# %%
customer_id_df.describe()
# Out:
#         Customer ID           Age  Income (USD/Month)
# count  49171.000000  49171.000000        49171.000000
# mean   28398.252283     35.363121        15015.631856
# std    17714.137333     12.599066         8002.208253
# min        1.000000     18.000000         2000.000000
# 25%    12654.500000     25.000000         8289.500000
# 50%    27631.000000     33.000000        14656.000000
# 75%    43284.500000     42.000000        21035.000000
# max    60000.000000     65.000000        35000.000000

# %%
#Read and understand datatype
#4.Transaction ID
transaction_id_df = pd.read_csv('Transaction_ID.csv')
transaction_id_df.head()
# Out:
#    Transaction ID  Customer ID Payment_Mode
# 0        10000011        29290         Card
# 1        10000012        27703         Card
# 2        10000013        28712         Cash
# 3        10000014        28020         Cash
# 4        10000015        27182         Card

# %%
transaction_id_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440098 entries, 0 to 440097
# Data columns (total 3 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  440098 non-null  int64
#  1   Customer ID     440098 non-null  int64
#  2   Payment_Mode    440098 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 10.1+ MB

# %%
transaction_id_df.dtypes
# Out:
# Transaction ID     int64
# Customer ID        int64
# Payment_Mode      object
# dtype: object

# %%
transaction_id_df.describe()
# Out:
#        Transaction ID    Customer ID
# count    4.400980e+05  440098.000000
# mean     1.022006e+07   23619.513120
# std      1.270455e+05   21195.549816
# min      1.000001e+07       1.000000
# 25%      1.011004e+07    3530.000000
# 50%      1.022006e+07   15168.000000
# 75%      1.033008e+07   43884.000000
# max      1.044011e+07   60000.000000

# %%
#Finding null value for cab data
cab_df.isnull().sum()
# Out:
# Transaction ID    0
# Date of Travel    0
# Company           0
# City              0
# KM Travelled      0
# Price Charged     0
# Cost of Trip      0
# dtype: int64

# %%
#Finding null value for city data
city_df.isnull().sum()
# Out:
# City          0
# Population    0
# Users         0
# dtype: int64

# %%
#Finding null value for customer id data
customer_id_df.isnull().sum()
# Out:
# Customer ID           0
# Gender                0
# Age                   0
# Income (USD/Month)    0
# dtype: int64

# %%
#Finding null value for Transaction id data
transaction_id_df.isnull().sum()
# Out:
# Transaction ID    0
# Customer ID       0
# Payment_Mode      0
# dtype: int64

# %%
#Identify and remove duplicates cab data
cab_df[cab_df.duplicated(subset=['Transaction ID'])]
# Out:
# Empty DataFrame
# Columns: [Transaction ID, Date of Travel, Company, City, KM Travelled, Price Charged, Cost of Trip]
# Index: []

# %%
#Identify and remove duplicates city data
city_df[city_df.duplicated(subset=['City'])]
# Out:
# Empty DataFrame
# Columns: [City, Population, Users]
# Index: []

# %%
#Identify and remove duplicates Customer data 
customer_id_df[customer_id_df.duplicated(subset=['Customer ID'])]
# Out:
# Empty DataFrame
# Columns: [Customer ID, Gender, Age, Income (USD/Month)]
# Index: []

# %%
#Identify and remove duplicates Transaction data
transaction_id_df[transaction_id_df.duplicated(subset=['Transaction ID'])]
# Out:
# Empty DataFrame
# Columns: [Transaction ID, Customer ID, Payment_Mode]
# Index: []

# %%
#Merge and Visualize the Whole Dataset
df= cab_df.merge(transaction_id_df, on= 'Transaction ID').merge(customer_id_df, on ='Customer ID').merge(city_df, on = 'City')
df.head()
# Out:
#    Transaction ID  Date of Travel     Company        City  KM Travelled  \
# 0        10000011           42377    Pink Cab  ATLANTA GA         30.45
# 1        10351127           43302  Yellow Cab  ATLANTA GA         26.19
# 2        10412921           43427  Yellow Cab  ATLANTA GA         42.55
# 3        10000012           42375    Pink Cab  ATLANTA GA         28.62
# 4        10320494           43211  Yellow Cab  ATLANTA GA         36.38
#
#    Price Charged  Cost of Trip  Customer ID Payment_Mode Gender  Age  \
# 0         370.95      313.6350        29290         Card   Male   28
# 1         598.70      317.4228        29290         Cash   Male   28
# 2         792.05      597.4020        29290         Card   Male   28
# 3         358.52      334.8540        27703         Card   Male   27
# 4         721.10      467.1192        27703         Card   Male   27
#
#    Income (USD/Month) Population     Users
# 0               10813   814,885    24,701
# ...

# %%
#Visualize the Data
sns.pairplot(df.head(1000), hue = 'Company')

# %%
#Check the Correlation
data_corr = df.corr()
data_corr
# Out:
#                     Transaction ID  Date of Travel  KM Travelled  \
# Transaction ID            1.000000        0.993030     -0.001429
# Date of Travel            0.993030        1.000000     -0.001621
# KM Travelled             -0.001429       -0.001621      1.000000
# Price Charged            -0.052902       -0.055559      0.835753
# Cost of Trip             -0.003462       -0.004484      0.981848
# Customer ID              -0.016912       -0.017653      0.000389
# Age                      -0.001267       -0.001346     -0.000369
# Income (USD/Month)       -0.001570       -0.001368     -0.000544
#
#                     Price Charged  Cost of Trip  Customer ID       Age  \
# Transaction ID          -0.052902     -0.003462    -0.016912 -0.001267
# Date of Travel          -0.055559     -0.004484    -0.017653 -0.001346
# KM Travelled             0.835753      0.981848     0.000389 -0.000369
# Price Charged            1.000000      0.859812    -0.177324 -0.003084
# ...

# %%
#from Heat map visuvalize master data
# Define the figure size
plt.figure(figsize = (20,15))

# Cutomize the annot
annot_kws={'fontsize':10,                      # To change the size of the font
           'fontstyle':'italic',               # To change the style of font 
           'fontfamily': 'serif',              # To change the family of font 
           'alpha':1 }                         # To change the transparency of the text  


# Customize the cbar
cbar_kws = {"shrink":1,                        # To change the size of the color bar
            'extend':'min',                    # To change the end of the color bar like pointed
            'extendfrac':0.1,                  # To adjust the extension of the color bar
            "drawedges":True,                  # To draw lines (edges) on the color bar
           }

# take upper correlation matrix
matrix = np.triu(data_corr)

# Generate heatmap correlation
ax = sns.heatmap(data_corr, mask = matrix, cmap = 'rainbow', annot = True, linewidth = 1.5 ,annot_kws= annot_kws, cbar_kws=cbar_kws)

# Set the title etc
plt.title('Correlation Heatmap of "G2M Insight for Cab Investment", fontsize = 20')

# Set the size of text
sns.set(font_scale = 1.2)

# %%
#Investigate the Data
#1.User Travel
user=df.groupby('Company').Users.count()
index = user.index
value = user.values

# %%
figp, axp = plt.subplots(figsize=(10,7))
axp.pie(value , labels=index, autopct='%1.1f%%',shadow=True, startangle=90,)
axp.axis('equal')

plt.title('Users Travel', fontsize = 15)
plt.show()

# %%
# 2.KM Travelled Distribution
plt.figure(figsize = (20,12))
plt.hist(df['KM Travelled'], bins = 50)
plt.title('Km Travelled Distribution', fontsize=20)
plt.ylabel('Frequency')
plt.xlabel('Km Travelled')
plt.show()

# %%
#import warning
import warnings
warnings.filterwarnings("ignore")

# %%
#3.Price Charged
sns.set(style = 'whitegrid')

plt.figure(figsize = (20,15))

sns.boxplot(df['Company'], df['Price Charged'])
plt.title('Price Charged of Both Companies', fontsize=20)
plt.show()

# %%
#4.Cost of Trip
company = df.groupby('Company')
cost_trip = company['Cost of Trip'].mean()
c = cost_trip.index
c_v = cost_trip.values
plt.style.use('fivethirtyeight')
plt.figure(figsize = (16, 9))
plt.bar(c, c_v, edgecolor='black', label="Profit")
plt.title('Cost of Trip for both company')
plt.ylabel('Cost of Trip')
plt.xlabel('Company')
plt.legend()
plt.show()

# %%
#5.Average Age of Users
sns.set(style = 'darkgrid')
plt.figure(figsize = (15, 6))
sns.barplot(x ='Gender', y ='Age', data = df,hue = "Company")
plt.title('Avg age of users', fontsize=20)
plt.show()

# %%
#6.Average Income
sns.set(style = 'darkgrid') 

plt.figure(figsize = (12, 6))

sns.violinplot(df['Company'], df['Income (USD/Month)'], palette = 'husl', inner = 'quartiles')
plt.title('Average Income', fontsize=20)
plt.show()

# %%
#Create multiple hypothesis and investigate
#Hypothesis 1:There is no difference regarding Gender in pink cab companies.
df['Profit'] = df['Price Charged'] - df['Cost of Trip']
a = df[(df.Gender=='Male')&(df.Company=='Pink Cab')].groupby('Transaction ID').Profit.mean()
b = df[(df.Gender=='Female')&(df.Company=='Pink Cab')].groupby('Transaction ID').Profit.mean()
print(a.shape[0],b.shape[0])

_, p_value = stats.ttest_ind(a.values,
                             b.values,
                             equal_var=True)

print('P value is ', p_value)

if(p_value<0.05):
    print('We accept  hypothesis that there is a difference regarding gender for Pink Cab')
else:
    print('We accept hypothesis that there is no difference regarding gender for Pink Cab')
# Out:
# 47231 37480
# P value is  0.11515305900425798
# We accept hypothesis that there is no difference regarding gender for Pink Cab

# %%
#Hypothesis 2:There is difference regarding Gender in yellow cab companies.
a = df[(df.Gender=='Male')&(df.Company=='Yellow Cab')].groupby('Transaction ID').Profit.mean()
b = df[(df.Gender=='Female')&(df.Company=='Yellow Cab')].groupby('Transaction ID').Profit.mean()
print(a.shape[0],b.shape[0])

_, p_value = stats.ttest_ind(a.values,
                             b.values,
                             equal_var=True)

print('P value is ', p_value)

if(p_value<0.05):
    print('We accept hypothesis  that there is a difference regarding gender for Yellow Cab')
else:
    print('We accept hypothesis that there is no difference regarding gender for Yellow Cab')
# Out:
# 158681 116000
# P value is  6.060473042494144e-25
# We accept hypothesis  that there is a difference regarding gender for Yellow Cab

# %%
#Hypothesis 3:There is no difference regarding age for Pink Cab
a = df[(df.Age <= 50)&(df.Company=='Pink Cab')].groupby('Transaction ID').Profit.mean()
b = df[(df.Age >= 50)&(df.Company=='Pink Cab')].groupby('Transaction ID').Profit.mean()
print(a.shape[0],b.shape[0])

_, p_value = stats.ttest_ind(a.values,
                             b.values,
                             equal_var=True)

print('P value is ', p_value)

if(p_value<0.05):
    print('We accept hypothesis that there is a difference regarding age for Pink Cab')
else:
    print('We accept hypothesis that there is no difference regarding age for Pink Cab')
# Out:
# 71228 14405
# P value is  0.3905344473325604
# We accept hypothesis that there is no difference regarding age for Pink Cab

# %%
#Hypothesis 4:There is a difference regarding age for Yellow Cab
a = df[(df.Age <= 50)&(df.Company=='Yellow Cab')].groupby('Transaction ID').Profit.mean()
b = df[(df.Age >= 50)&(df.Company=='Yellow Cab')].groupby('Transaction ID').Profit.mean()
print(a.shape[0],b.shape[0])

_, p_value = stats.ttest_ind(a.values,
                             b.values,
                             equal_var=True)

print('P value is ', p_value)

if(p_value<0.05):
    print('We accept hypothesis that there is a difference regarding age for Yellow Cab')
else:
    print('We accept hypothesis that there is no difference regarding age for Yellow Cab')
# Out:
# 231480 46368
# P value is  3.893841736668538e-05
# We accept hypothesis that there is a difference regarding age for Yellow Cab

# %%
#Hypothesis 5:there is no difference in payment mode for Pink Cab
a = df[(df['Payment_Mode']=='Cash')&(df.Company=='Pink Cab')].groupby('Transaction ID').Profit.mean()
b = df[(df['Payment_Mode']=='Card')&(df.Company=='Pink Cab')].groupby('Transaction ID').Profit.mean()

_, p_value = stats.ttest_ind(a.values,
                             b.values,
                             equal_var=True)

print('P value is ', p_value)

if(p_value<0.05):
    print('We accept hypothesis that there is a difference in payment mode for Pink Cab')
else:
    print('We accept hypothesis that there is no difference in payment mode for Pink Cab')
# Out:
# P value is  0.7900465828793288
# We accept hypothesis that there is no difference in payment mode for Pink Cab

# %%
#Hypothesis 6:There is no difference in payment mode for Yellow Cab
a = df[(df['Payment_Mode']=='Cash')&(df.Company=='Yellow Cab')].groupby('Transaction ID').Profit.mean()
b = df[(df['Payment_Mode']=='Card')&(df.Company=='Yellow Cab')].groupby('Transaction ID').Profit.mean()

_, p_value = stats.ttest_ind(a.values,
                             b.values,
                             equal_var=True)

print('P value is ', p_value)

if(p_value<0.05):
    print('We accept hypothesis that there is a difference in payment mode for Yellow Cab')
else:
    print('We accept hypothesis that there is no difference in payment mode for Yellow Cab')
# Out:
# P value is  0.2933060638298729
# We accept hypothesis that there is no difference in payment mode for Yellow Cab
